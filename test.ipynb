# %%
import streamlit as st
from pylovepdf.ilovepdf import ILovePdf
import tempfile
from pathlib import Path
import os
import shutil
import zipfile
from datetime import datetime

# %%
public_key = xxx
ilovepdf = ILovePdf(public_key, verify_ssl=False)

# %%
task = ilovepdf.new_task('compress')
task.add_file('TEST_IN_1.pdf')
task.set_output_folder('tmp/')
task.execute()
task.download()
task.delete_current_task()
# Out:
# Uploading file...
# File uploaded! Below file stats:
# download_filename: TEST_IN_1_compress_10-11-2025.pdf
# filesize: 14041003
# output_extensions: ["pdf"]
# output_filenumber: 1
# output_filesize: 4545125
# status: TaskSuccess
# timer: 3.893
#
# Downloading processed file...
# File downloaded!
# Task delete status: 200
